# %% [markdown]
# <a href="https://colab.research.google.com/github/devikanimnadi/03_Python_Functions/blob/main/Python_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Functions**
# Functions are reusable blocks of code for specific tasks. They help keep  code as short and easy to work with as possible, saving you from repeating code.
#
# #built-in functions
#  Python has many built-in functions which  can re-use in  code by calling them.
#  ex:
#  print()
#  range()
#  type()
#
# ##function can be argument for another functions
# ```python
# print(range(3))
# ```
# ###upper()
# ```python
# print('smarTpHone'.lower())
# print('smarTpHone'.upper())
# print('smarTpHone'.capitalize())
# ```
# ```
# smartphone
# smartphone
# SMARTPHONE
# Smartphone
# ```
#
# Strings are immutable and functions won't change them. You'll need to store the modified string in a variable to keep it.
# ```python
# item="naME"
# print(item.upper())
# print(item)
# item2=item.upper()
# print(item2)
# ```
# ```
# NAME
# naME
# NAME
# ```
# ##find()
# The find() function checks if a character (or a pattern of characters) is present in a string. The function returns the index (position) of the given value. If the given value is present multiple times, the function will return the first occurrence (the lowest index).
# ```puthon
# print("robot".find("o"))
# print("robot".find("A"))
# ```
# ```
# 1
# -1
# ```
# ##len()
#  it returns the number of items in the list.
#  The len() function is not only for lists. It accepts as an argument any sequence, including strings.
#  ```python
#  movie = "Avatar"
#  print(len(movie))
#  ```
#  ```
#  6
#  ```
#  ##**append()**
#
# The append() function adds a new item to the end of a list.
# ```python
# movies=["Avatar","Titanic","Avengers"]
# movies.append("Alien")
# print(movies)
# ```
# ```
# ['Avatar', 'Titanic', 'Avengers', 'Alien']
# ```
# ##insert()
# The insert() function allows  to add an element to a list, at a specific position.
# ```python
# movies=["Avatar","Titanic","Avengers"]
# movies.insert(1,"haripoter")
# print(movies)
# ```
# ```
# ['Avatar', 'haripoter', 'Titanic', 'Avengers']
# ```
# ##pop()
# The pop() function removes an element from a list.
# ```python
# topic = ["Maths","English","Physics"]
# topic.pop(2)
# print(topic)
# ```
# ```
# ["Maths", "English"]
# ```
# #**custom function**
# ```python
# def greet():
#   print("Hello from a function")
#   print("Have a great day")
#
# greet()
# ```
# ```
# Hello from a function
# Have a great day
# ```
#
# ##custom functions with argument
# ex:
#
# ```python
# def rect(d1, d2):
#   area = d1 * d2
#   perimeter = 2 * d1 + 2 * d2
#   price = 1000 * area
#   return area, perimeter, price
#
# print(rect(3,4))
# ```
# ```
# (12, 14, 12000)
# ```
# ex:
# ```python
# def add(b,a):
#   total=a+b
#   print("a:%d     b:%d" %(a,b))
#   print("The sum is ",total)
#
# add(a=10,b=20)
# ```
# ```
# a:10     b:20
# The sum is  30
# ```
# if we use more arguments,
# ```python
# def add(*a):
#   total=0
#   for i in a:
#     total=total+i
#   print("The sum is ",total)
#
# add(10,20,30,40)
# add(1)
# ```
# ```
# The sum is  100
# The sum is  1
# ```
# ```python
# def add(a,b):
#   a=2
#   b=3
#   total=a+b
#   print("The sum is", total)
#
# x=10
# y=20
# add(x,y)
# print("the sum is", x+y)
#
# ```
# ```
# The sum is 5
# the sum is 30
# ```
# ```pyhton
# def welcome():
#   print("Good morning")
#
# def add(a,b):
#   print(id(a),id(b))
#   a=2
#   b=3
#   print(id(a),id(b))
#   total=a+b
#   print("The sum is",total)
#
# x=10
# y=20
# print(id(x),id(y))
# add(x,y)
# print("the sum is",x+y)
#
# ```
# ```
# 10758024 10758344
# 10758024 10758344
# 10757768 10757800
# The sum is 5
# the sum is 30
# ```
#
#
# ##custom function with default values
# ```python
# def greet(name="Guest"):
#   print("Welcome", name)
# greet()
# greet("Anna")
# ```
# ```
# Welcome Guest
# Welcome Anna
# ```
# ```pyhton
# def add(a=0,b=0):
#   total=a+b
#   print("a:%d     b:%d" %(a,b))
#   print("The sum is ",total)
#
# add(10)
# ```
# ```
# a:10     b:0
# The sum is  10
# ```
#
# #**Higher-Order Functions**
# functions that operate with other functions — that is, take another function as an argument or return a function -  are called Higher-Order Functions. They are particularly useful for processing various functions and returning specific results.
# ```python
# def book_title(title):
#   return "Book title: " + title
# def info(title, func):
#   return func(title)
#
# print(info("The Great Gatsby", book_title))
# ```
# ```
# Book title: The Great Gatsby
# ```
# #**Pure Functions**
# Pure functions always return the same value for the same arguments and do not produce any side effects
# ```python
# def total(price,count):
#   return price*count
# ```
# #**impure Functions**
#
# #**Lambda expression**
# They are written in just one line using the lambda keyword and are often used for small, simple tasks.
#
# Lambda expressions perform a single operation and return a result.
# ```python
# # def greet(name):
# #   return "welcome,"+name
# lambda name:"welcome,"+name
# ```
# **Lambda expressions can take multiple arguments separated by commas**
# type1
# ```python
# x = lambda price, count :  price * count
# print(x(2,10))
# ```
# type2
# we can add arguments like this
# ```python
# x = (lambda price, count :  price * count)(2,10)
# print(x)
# ```
# #**map()**
# #map(<function>,<iterable>)
# The map() function applies a specified function to every element in an iterable, like lists or tuples. It produces a result that can be transformed into a list using the list() function for easy viewing or further use.
# ```python
# prices = [25.99, 14.50, 8.75, 19.95]
# def discount(price):
#   discounted_price = price * 0.9
#   return discounted_price
#
# discounted_prices = list(map(discount, prices))
# print(discounted_prices)
# ```
# [23.391, 13.05, 7.875, 17.955]
# ```
# #**lambda expressions with map**
# ```python
# numbers=[1,2,3]
# doubled=list(map(lambda x:x*2,numbers))
# print(doubled)
# ```
# ```
# [2, 4, 6]
# ```
# #**filter() function**
# just like the map() function, takes in a function and an iterable as arguments.
# key purpose:
# return only those for which the function evaluates to True.
# ```python
# products=["Table","Sofa","Cushion","Bookshelf","vase"]
# #filters products with name length equal to 4
# filtered_prod=list(filter(lambda name: len(name)==4,products))
# print(filtered_prod)
# ```
# ```
# ['Sofa', 'vase']
# ```
# ```python
# products={'Table':110,'Sofa':120,'Chair':45,'Lamp':70}
# #filtering product with prices less than 90
# filtered_products=dict(filter(lambda item:item[1]<90,products.items()))
# print(filtered_products)
# ```
# ```
# {'Chair': 45, 'Lamp': 70}
# ```
# #**number of arguments of the fuction is unknown**
# can always use an iterable as an arguments.
#
# Ex:using a list as an argument.
# ```python
# def total(numbers):
#   result=0
#   #iterating over the list
#   for i in numbers:
#     result+=i
#   return result
#
# nums=[1,2,3,4,5]
#
# print(total(nums))
# ```
# ##*args
# *args allows you to provide any number of arguments without the need to create a list before calling the function each time.
# args id just a name.we can use any name for that.
#
# ```python
# def display(*words):
#   for item in words:
#     print(item)
# display("paper", "pen", "pencil")
# ```
# ```
# paper
# pen
# pencil
# ```
# #**<func>(<argument>,<*args>)**
# When defining a function with both regular arguments and *args, the regular arguments must come before *args in the function definition.
# ```python
# def show_items(category,*items):
#   print("category:"+category)
#   for item in items:
#     print(item)
#
# show_items("Electronic","Laptop","Smartphone","Tablet")
# ```
# ```
# category:Electronic
# Laptop
# Smartphone
# Tablet
# ```
# #**kwarg
# **kwargs receives arguments in the form of a dictionary, consisting of key:value pairs.
# ```python
# #kwargs is a dictionary
# def display_info(**kwargs):
#   #kwargs.items() returns the key:value pairs
#   for key,value in kwargs.items():
#     print(key,",",value)
#
# display_info(name="Alice",age=30,city="New york")
# ```
# ```
# name , Alice
# age , 30
# city , New york
# ```
#
# #**order of arguments**
# In a function definition, the order of arguments is important. First, regular arguments are listed, followed by *args for positional arguments, and finally **kwargs for keyword arguments.
#
# def<func>(<argument>,<*args>,<**kwargs>)
#
# #functions can be nested
# ```python
# #outer/ parent function
# def outer_function():
#   print("Hello from the outer function")
#
#   #inner/child function
#   def inner_function():
#     print("Hello from the inner function")
#
#   inner_function()
#
# outer_function()
#
# ```
# ```python
# def order():
#   def prepare():
#     return "Your meal is being prepared!"
#   status = prepare()
#   return status
#
# print(order())
# ```
# ```
# Your meal is being prepared!
# ```
#
# #**decorators**
# ```python
# def uppercase(func):
#     def wrapper():
#         result = func()
#         return result.upper()
#     return wrapper
#
# @uppercase
# def greet():
#     return "hello world"
#
#
# print(greet())
# ```
# ```
# HELLO WORLD
# ```
# ```python
# def uppercase(func):
#     def wrapper(*args):
#         result = func(*args)
#         return result.upper()
#     return wrapper
#
# @uppercase
# def greet(name,age,city):
#     return f"{name} is {age} years old and he lives in {city}."
#
#
# print(greet("jim ",23,"maharagama"))
# ```
# ```
# JIM IS 23 YEARS OLD AND HE LIVES IN MAHARAGAMA.
# ```
